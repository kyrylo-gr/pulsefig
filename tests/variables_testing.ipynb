# %%
# %load_ext autoreload
# %autoreload 2

from pulsefig.variables import UnsetParameter


class Test:
    param = UnsetParameter()

    def __init__(self):
        pass
# Out:
# The autoreload extension is already loaded. To reload it, use:
#   %reload_ext autoreload

# %%
t = Test()
a = t.param + 2
print(a)
t.param = 3
print(float(a))
# Out:
# FloatProxy Link to <__main__.Test object at 0x11cb35a20>._param = 0.0
# 5.0

# %%
t = Test()

a = t.param
b = t.param

# %%
a.link, b.link
# Out:
# (Link to <__main__.Test object at 0x11cc4d0f0>._param,
#  Link to <__main__.Test object at 0x11cc4d0f0>._param)

# %%
hash(a), hash(b)
# Out:
# (-2290080528297569959, -2290080528297874177)
